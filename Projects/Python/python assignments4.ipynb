# %%
H = [1,4,'haydar', [5,7],'mhamad']
print(H)

# %%
for i in range(6):
  for a in range(i):
    print('*',end= '')
  print('*')
# Out:
# *
# **
# ***
# ****
# *****
# ******

# %%
age = float(input("please enter your age"))
minor = 0
adult = 0
old = 0
if age<18 :
  minor += 1
  print("minor", minor)
elif 18<= age <= 64:
  adult += 1
  print("adult", adult)
else:
  old += 1
  print("old", old)

# %%
for i in range(0,100):
  print(str(i)+("*"))
  for i in range(101,200):
    print(str(i)+("*"))

for i in range(6):
  print(i)

for i in range(6):
  for a in range(i):
    print('*',end= '')
  print('*')

age = float(input("please enter your age"))
minor = 0
adult = 0
old = 0
if age<18 :
  minor += 1
  print("minor", minor)
elif 18<= age <= 64:
  adult += 1
  print("adult", adult)
else:
  old += 1
  print("old", old)

age = 68
is_full_time_student = True
age = float(input(' please enter your age'))
if age < 19 or is_full_time_student:
    result = True
else:
    result = False
    print(result)

H = [1,2,3,4,5,6,7,8,9]
l1 =[]
l2=[]

age = 45
is_full_time_student = True
myrules = age<19 or is_full_time_student == True
print(myrules)

H = [1,4,'haydar', [5,7],'mhamad']
print(H)
H[4]= 'maria'
print(H[4])
H[3][-1]
print(H[3][-1])

H = (1,4,'haydar', [5,7],'mhamad')
print(H)

H = (1,4,'haydar', [5,7,[1,2,[5,6]]],'mhamad')
print(H)

l = [1,5,8,7,1,0,3,6,99,87,55,847,7,5,3,1,5767,234,875,1234465,77954,2.45]
l1 = []
l2 = []
for i in range(len(l)):
  if l[i] % 2 ==0:
    l2.append(l[i])
  else:
    l1.append(l[i])
print(l1)
print(l2)

def add(a,b):
  c= a+b
  print(c)
add(4,7)

from pickle import LIST
def haydar(l):
  for i in range(len(l)):
    if l[i] % 2 ==0:
      print(l[i])
l1=[24,26,356,8,5,4,8,655,655,2,366,148,24886,2695,3365,9]
li=[2,3,6,5,9,8,7,9,8,4,3,5,6,9,6,8,5,6,5,6,8]
haydar(li)
haydar(l1)

def haydar(l):
  h2=[]
  for i in l:
    if i % 2 ==0:
      h2.append(i)
  return h2
l=[2,3,6,9,5,8,4,86,5,4,6]
r=haydar(l)

r=haydar(l)
print(r)

def plus(*h):
  for i in l:
    if i%2 ==0:

def plus(*h):
  m=0
  for i in h:
    m+=i
  print(m)
plus(2,6,9,8,7,6,5,3,1,2,5)
plus(2,6,9,8,4,2,6,4)

def pr(firstN,LastN):
  print('hello '+ firstN +""+ LastN)

pr('john ','evans ')

def br(ln,mn,fn='Merry '):
  print('hello and: '+ fn + mn +" "+ ln)
br('haydar ','christmas 🎄🎄🎇✨ ')

={
      'id':10121673,
      'Fname': 'haydar',
      'lname': 'mhamd',
      'hobbies': 'football',

}
ltwo={
      'id':10121674,
      'fname': 'ali',
      'lname': 'baba',
      'hobbies': 'drawing',
}
lthree={
        'id': 10121675,
        'fname': 'alaa',
        'lname': 'eddine',
        'hobbies': 'swimming',
}

# Prompt user to enter a sentence
sentence = input("Enter a sentence: ")

# Tokenize the sentence into words
words = sentence.split()

# Use a dictionary to keep track of word frequencies
word_frequencies = {}
for word in words:
    word_frequencies[word] = word_frequencies.get(word, 0) + 1

# Print the word frequencies
print("Word Frequencies:", word_frequencies)

S1= {
    'ID': 101220007,
    'FNAME': 'HAYDAR',
    'LNAME': 'MHAMD',
    'ADDRESS':'SINGAPHORE',
    'HOBBIES': [S1]
}
S1['FNAME']
S= {
    101220007 :{'FNAME': 'HAYDAR','LNAME': 'MHAMAD'}
}
S[101220007]

luno=[10121673,10121674,10121675,10121676]
lduo=['haydar🧛‍♂️','ali🤶','alaa👦','kassem🧔']
ltrio=['mhamad','baba','eddine','danach']
lsquad=[['football⚽','drawing🖌'],['swimming🛶'],['reading📕'],['running🏃‍♂️']]
def customerInfo(luno,lduo,ltrio,lsquad):
  Customer={}
  for i in range(len(luno)):
    Customer[luno[i]]={
                        'fname':lduo[i],'lname':ltrio[i],'hobbies':lsquad[i]}
  return Customer
customerInfo(luno,lduo,ltrio,lsquad)

customerInfo(luno,lduo,ltrio,lsquad)

luno=[10121673,10121674,10121675,10121676]
  lduo=['haydar','ali','alaa','kassem']
  ltrio=['mhamad','baba','eddine','danach']
  lsquad=[['football','drawing'],['swimming'],['reading'],['running']]
